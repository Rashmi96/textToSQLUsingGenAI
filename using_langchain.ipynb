# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashmi96/textToSQLUsingGenAI/blob/master/using_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-community
# !pip install langchain-experimental
# !pip install sqlalchemy sqlite3
# !pip install langchain-groq --upgrade # Ensure langchain-groq is upgraded to latest version

# Import create_csv_agent from langchain_experimental
from langchain_community.agent_toolkits.sql.base import create_sql_agent
from langchain.agents.agent_types import AgentType
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from langchain_groq import ChatGroq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
# ...

# %%
from re import VERBOSE
llm = ChatGroq(groq_api_key="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",model_name="llama-3.1-70b-versatile",streaming=True)

db = SQLDatabase.from_uri("sqlite:///Chinook_Sqlite.sqlite")
tables = db.get_usable_table_names()
for table in tables:
  print("tables in the DB",table)
toolkit = SQLDatabaseToolkit(db=db,llm=llm)

agent = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    verbose=True,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
)

agent.run("get all the artists in Album table?")
# Out:
# > Entering new SQL Agent Executor chain...
# Thought: I should look at the tables in the database to see what I can query.
# Action: sql_db_list_tables
# Action Input: Observation: Album, Artist, Genre, MediaType, Playlist, PlaylistTrack, Track
#
# Thought: Now that I know the tables in the database, I can query the schema of the Album and Artist tables to see what columns are available.
#
# Action: sql_db_schema
# Action Input: Album, ArtistError: table_names {'Album', 'Artist'} not found in databaseThought: I've encountered an error while trying to query the schema of the Album and Artist tables. I'll try again, but first, I'll double check if the table names are correct by listing the tables in the database again.
#
# Action: sql_db_list_tables
# Action Input: Observation: Album, Artist, Genre, MediaType, Playlist, PlaylistTrack, Track
#
# ...
